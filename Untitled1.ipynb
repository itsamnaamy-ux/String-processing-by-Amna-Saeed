# %% [markdown]
# <a href="https://colab.research.google.com/github/itsamnaamy-ux/String-processing-by-Amna-Saeed/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = "Hello Python Programming"
print(text)
# Out:
# Hello Python Programming

# %%
print(text[0:5])   # First character
print(text[6:25])   # Character at index 6
# Out:
# Hello
# Python Programming

# %%
print(text[0])   # First character
print(text[6])   # Character at index 6
# Out:
# H
# P

# %%
print(text.upper())
print(text.lower())
# Out:
# HELLO PYTHON PROGRAMMING
# hello python programming

# %%
print(text.capitalize())
print(text.title())
# Out:
# Hello python programming
# Hello Python Programming

# %%
print("Python" in text)
# Out:
# True

# %%
print(text.find("Python"))
# Out:
# 6

# %%
print(text.replace("Python", "Anaconda"))
# Out:
# Hello Anaconda Programming

# %%
text2 = "   Hello Anaconda   "
print(text2.strip())
# Out:
# Hello Anaconda

# %%
words = text.split()
print(words)
# Out:
# ['Hello', 'Python', 'Programming']

# %%
joined_text = "-".join(words)
print(joined_text)
# Out:
# Hello-Python-Programming

# %%
print(text.count("o"))
# Out:
# 3

# %%
str1 = "Hi!"
str2 = "Anaconda"
print(str1 + " " + str2)
# Out:
# Hi! Anaconda

# %%
print(str1 * 3)
# Out:
# Hi!Hi!Hi!

# %%
a = "Anaconda"
b = "python"

print(a == b)
# Out:
# False
